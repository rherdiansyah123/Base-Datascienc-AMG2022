# %%
import matplotlib.pyplot as plt

# %%
print("======== SOAL NO 1 ========")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['paskibra', 'PMR', 'pramuka', 'futsal', 'volly', 'kesenian', 'rohis']
mengikuti = [5, 18, 30, 7, 16, 19, 12]
c = ['red', 'green', 'blue', 'red', 'green', 'blue']
plt.title("ESKUL")
plt.bar(eskul, mengikuti, color = c)
plt.show()

print("======== SOAL NO 2 ========")
a = 5
b = 21
c = 6
jml = (a + b) + (c)
print("yang mengikuti PASKIBRA : " + str(jml))

a = 18
b = 4
c = 12
jml = (a + b) + (c)
print("yang mengikuti PMR : " + str(jml))

a = 30
b = 8
c = 24
jml = (a + b) + (c)
print("yang mengikuti PRAMUKA : " + str(jml))

a = 7
b = 29
c = 15
jml = (a + b) + (c)
print("yang mengikuti PUTSAL : " + str(jml))

a = 16
b = 10
c = 12
jml = (a + b) + (c)
print("yang mengikuti VOLLY : " + str(jml))

a = 19
b = 18
c = 4
jml = (a + b) + (c)
print("yang mengikuti KESENIAN : " + str(jml))

a = 12
b = 10
c = 7
jml = (a + b) + (c)
print("yang mengikuti ROHIS : " + str(jml))

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['PASKIBRA', 'PMR', 'PRAMUKA', 'FUTSAL', 'VOLLY', 'KESENIAN', 'ROHIS']
mwngikuti = [32, 34, 62, 51, 38, 41, 29]
c = ['red', 'green', 'blue', 'red', 'green', 'blue']
plt.title("ESKUL")
plt.bar(eskul, mengikuti, color = c)
plt.show()

print("")
print("======== SOAL NO 3 ========")
a = 7
b = 29
c = 15
d = 16
e = 10
f = 12
m = 287
td = 45

hasil = (a + b + c + d + e + f)
hasil2 = (m - hasil)
print(hasil2)
print(hasil)
print(td)
hasil3 = (hasil2 / 332) * 10
hasil4 = (td / 332) * 10
hasil5 = (hasil / 332) * 10
print(hasil3)
print(hasil4)
print(hasil5)

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['OLAHRAGA', 'MENGIKUTI', 'TIDAK MENGIKUTI']
mengikuti = [17, 8, 20]
c = ['red', 'green', 'blue', 'red', 'green', 'blue']
plt.title("ESKUL")
plt.bar(eskul, mengikuti, color = c)
plt.show()

print("")
fig =plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('equal')
plt.title("ESKUL")
eskul = ['OLAHRAGA', 'MENGIKUTI', 'TIDAK MENGIKUTI']
mengikuti = [17, 8, 20]
ax.pie(mengikuti,labels = eskul,autopct ='%1.2f%%')
plt.show()


print("")
print("======== SOAL NO 4 ========")
a = 17
b = 8
c = 20
hasil = (a + b) + (c)

print("yang tidak mengikuti eskul = " + str(hasil))
presentanseu = [32.7, 17.7, 44.4]
print("maka presentanseu nya adalah. " + str(presentanseu))

print("")
print("======== SOAL NO 5 ========")

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['paskibra', 'pmr', 'pramuka', 'futsal', 'volly', 'kesenian', 'rohis']
mengikuti = [5, 18, 30, 7, 16, 19, 12]
c = ['red', 'green', 'blue', 'red', 'green', 'blue']
plt.title("kelas 10")
plt.bar(eskul, mengikuti, color = c)
plt.show()

print("")
fig =plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('equal')
plt.title("kelas 10")
eskul = ['paskibra', 'pmr', 'pramuka', 'futsal', 'volly', 'kesenian', 'rohis']
mengikuti = [5, 18, 30, 7, 16, 19, 12]
ax.pie(mengikuti,labels = eskul,autopct ='%1.2f%%')
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['paskibra', 'pmr', 'pramuka', 'futsal', 'volly', 'kesenian', 'rohis']
mengikuti = [21, 4, 8, 29, 10, 18, 10]
c = ['red', 'green', 'blue', 'red', 'green', 'blue']
plt.title("kelas 11")
plt.bar(eskul, mengikuti, color = c)
plt.show()

print("")
fig =plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('equal')
plt.title("kelas 11")
eskul = ['paskibra', 'pmr', 'pramuka', 'futsal', 'volly', 'kesenian', 'rohis']
mengikuti = [21, 4, 8, 29, 10, 18, 10]
ax.pie(mengikuti,labels = eskul,autopct ='%1.2f%%')
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['paskibra', 'pmr', 'pramuka', 'futsal', 'volly', 'kesenian', 'rohis']
mengikuti = [6, 12, 24, 15, 12, 4, 7]
c = ['red', 'green', 'blue', 'red', 'green', 'blue']
plt.title("kelas 12")
plt.bar(eskul, mengikuti, color = c)
plt.show()

print("")
fig =plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('equal')
plt.title("kelas 12")
eskul = ['paskibra', 'pmr', 'pramuka', 'futsal', 'volly', 'kesenian', 'rohis']
mengikuti = [6, 12, 24, 15, 12, 4, 7]
ax.pie(mengikuti,labels = eskul,autopct ='%1.2f%%')
plt.show()
# Out:
# ======== SOAL NO 1 ========
# ======== SOAL NO 2 ========
# yang mengikuti PASKIBRA : 32
# yang mengikuti PMR : 34
# yang mengikuti PRAMUKA : 62
# yang mengikuti PUTSAL : 51
# yang mengikuti VOLLY : 38
# yang mengikuti KESENIAN : 41
# yang mengikuti ROHIS : 29
# ======== SOAL NO 3 ========
# 198
# 89
# 45
# 5.9638554216867465
# 1.355421686746988
# 2.680722891566265
# ======== SOAL NO 4 ========
# yang tidak mengikuti eskul = 45
# maka presentanseu nya adalah. [32.7, 17.7, 44.4]
#
# ======== SOAL NO 5 ========
